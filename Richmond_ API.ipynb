# %% [markdown]
# # Question: Optimal price to put in for bid on a house
# Greater Richmond Area Cities ML model to best predict bid price based on house characteristics
#
# Heatmap of selling prices based on selling price parsed by zip code Hover text with name, avg selling price, etc
#
# Parameter Limits: 1 bathroom, 1 bedroom, PropertyType = Single Family, Townhouse, Condo, Duplex-Triplex, Manufactured

# %%
# Import the dependencies.
import pandas as pd
import requests
import json

# Import API key
from config import API_KEY

# %%
# API setup

url = "https://realty-mole-property-api.p.rapidapi.com/saleListings"

querystring = {"zipCode":"23224","limit":"500"}

headers = {
	"X-RapidAPI-Key": API_KEY,
	"X-RapidAPI-Host": "realty-mole-property-api.p.rapidapi.com"
}

response_RichmondA = requests.request("GET", url, headers=headers, params=querystring).json()

print(json.dumps(response_RichmondA, indent=4, sort_keys=True))
# Out:
# [
#     {
#         "addressLine1": "2527 Goodes Bridge Rd",
#         "bedrooms": 0,
#         "city": "Richmond",
#         "county": "Chesterfield County",
#         "createdDate": "2022-07-17T06:21:04.428Z",
#         "daysOnMarket": 103,
#         "formattedAddress": "2527 Goodes Bridge Rd, Richmond, VA 23224",
#         "id": "2527-Goodes-Bridge-Rd,-Richmond,-VA-23224",
#         "lastSeen": "2022-11-17T11:41:30.289Z",
#         "latitude": 37.470924,
#         "listedDate": "2022-08-07T03:40:35.000Z",
#         "longitude": -77.519312,
#         "lotSize": 121576,
#         "price": 90000,
#         "propertyType": "Land",
#         "removedDate": null,
#         "state": "VA",
#         "status": "Active",
#         "zipCode": "23224"
#     },
#     {
#         "addressLine1": "2401 Clearfield St",
#         "city": "Richmond",
#         "county": "Richmond",
#         "createdDate": "2022-08-07T11:02:23.803Z",
#         "daysOnMarket": 185,
# ...

# %%
# API setup

url = "https://realty-mole-property-api.p.rapidapi.com/saleListings"

querystring = {"zipCode":"23220","limit":"500"}

headers = {
	"X-RapidAPI-Key": API_KEY,
	"X-RapidAPI-Host": "realty-mole-property-api.p.rapidapi.com"
}

response_RichmondB = requests.request("GET", url, headers=headers, params=querystring).json()

print(json.dumps(response_RichmondB, indent=4, sort_keys=True))
# Out:
# [
#     {
#         "addressLine1": "405 Catherine St",
#         "city": "Richmond",
#         "county": "Richmond",
#         "createdDate": "2022-08-07T11:03:57.716Z",
#         "daysOnMarket": 350,
#         "formattedAddress": "405 Catherine St, Richmond, VA 23220",
#         "id": "405-Catherine-St,-Richmond,-VA-23220",
#         "lastSeen": "2022-11-17T10:41:41.286Z",
#         "latitude": 37.550108,
#         "listedDate": "2021-12-02T18:24:38.000Z",
#         "longitude": -77.443664,
#         "lotSize": 871,
#         "price": 160000,
#         "propertyType": "Land",
#         "removedDate": null,
#         "state": "VA",
#         "status": "Active",
#         "zipCode": "23220"
#     },
#     {
#         "addressLine1": "1109 N Lombardy St",
#         "addressLine2": "Unit B",
#         "bathrooms": 2.5,
#         "bedrooms": 3,
#         "city": "Richmond",
#         "county": "Richmond",
#         "createdDate": "2022-08-07T10:49:24.999Z",
# ...

# %%
# API setup

url = "https://realty-mole-property-api.p.rapidapi.com/saleListings"

querystring = {"zipCode":"23221","limit":"500"}

headers = {
	"X-RapidAPI-Key": API_KEY,
	"X-RapidAPI-Host": "realty-mole-property-api.p.rapidapi.com"
}

response_RichmondC = requests.request("GET", url, headers=headers, params=querystring).json()

print(json.dumps(response_RichmondC, indent=4, sort_keys=True))
# Out:
# [
#     {
#         "addressLine1": "4106 Patterson Ave",
#         "bathrooms": 4.5,
#         "bedrooms": 5,
#         "city": "Richmond",
#         "county": "Richmond",
#         "createdDate": "2022-08-07T11:02:23.794Z",
#         "daysOnMarket": 169,
#         "formattedAddress": "4106 Patterson Ave, Richmond, VA 23221",
#         "id": "4106-Patterson-Ave,-Richmond,-VA-23221",
#         "lastSeen": "2022-11-17T10:41:41.277Z",
#         "latitude": 37.566493,
#         "listedDate": "2022-06-01T15:34:48.000Z",
#         "longitude": -77.489947,
#         "lotSize": 5401,
#         "price": 899900,
#         "propertyType": "Single Family",
#         "removedDate": null,
#         "squareFootage": 3445,
#         "state": "VA",
#         "status": "Active",
#         "yearBuilt": 2022,
#         "zipCode": "23221"
#     },
#     {
#         "addressLine1": "3129 Park Ave",
#         "bathrooms": 1.5,
#         "bedrooms": 4,
#         "city": "Richmond",
# ...

# %%
# API setup

url = "https://realty-mole-property-api.p.rapidapi.com/saleListings"

querystring = {"zipCode":"23219","limit":"500"}

headers = {
	"X-RapidAPI-Key": API_KEY,
	"X-RapidAPI-Host": "realty-mole-property-api.p.rapidapi.com"
}

response_RichmondD = requests.request("GET", url, headers=headers, params=querystring).json()

print(json.dumps(response_RichmondD, indent=4, sort_keys=True))
# Out:
# [
#     {
#         "addressLine1": "301 Virginia St",
#         "addressLine2": "Unit 1205",
#         "bathrooms": 2,
#         "bedrooms": 2,
#         "city": "Richmond",
#         "county": "Richmond",
#         "createdDate": "2022-10-14T08:46:34.692Z",
#         "daysOnMarket": 35,
#         "formattedAddress": "301 Virginia St, Unit 1205, Richmond, VA 23219",
#         "id": "301-Virginia-St,-Unit-1205,-Richmond,-VA-23219",
#         "lastSeen": "2022-11-17T10:39:47.575Z",
#         "latitude": 37.53267,
#         "listedDate": "2022-10-14T00:47:35.000Z",
#         "longitude": -77.433435,
#         "lotSize": 1350,
#         "price": 589500,
#         "propertyType": "Condo",
#         "removedDate": null,
#         "squareFootage": 1430,
#         "state": "VA",
#         "status": "Active",
#         "yearBuilt": 2007,
#         "zipCode": "23219"
#     },
#     {
#         "addressLine1": "6 N 6th St",
#         "addressLine2": "Apt 4D",
#         "bathrooms": 2,
# ...

# %%
# API setup

url = "https://realty-mole-property-api.p.rapidapi.com/saleListings"

querystring = {"zipCode":"23284","limit":"500"}

headers = {
	"X-RapidAPI-Key": API_KEY,
	"X-RapidAPI-Host": "realty-mole-property-api.p.rapidapi.com"
}

response_RichmondE = requests.request("GET", url, headers=headers, params=querystring).json()

print(json.dumps(response_RichmondE, indent=4, sort_keys=True))
# Out:
# []

# %%
# API setup

url = "https://realty-mole-property-api.p.rapidapi.com/saleListings"

querystring = {"zipCode":"23298","limit":"500"}

headers = {
	"X-RapidAPI-Key": API_KEY,
	"X-RapidAPI-Host": "realty-mole-property-api.p.rapidapi.com"
}

response_RichmondF = requests.request("GET", url, headers=headers, params=querystring).json()

print(json.dumps(response_RichmondF, indent=4, sort_keys=True))
# Out:
# []

# %%
# API setup

url = "https://realty-mole-property-api.p.rapidapi.com/saleListings"

querystring = {"zipCode":"23240","limit":"500"}

headers = {
	"X-RapidAPI-Key": API_KEY,
	"X-RapidAPI-Host": "realty-mole-property-api.p.rapidapi.com"
}

response_RichmondG = requests.request("GET", url, headers=headers, params=querystring).json()

print(json.dumps(response_RichmondG, indent=4, sort_keys=True))
# Out:
# []

# %%
# API setup

url = "https://realty-mole-property-api.p.rapidapi.com/saleListings"

querystring = {"zipCode":"23218","limit":"500"}

headers = {
	"X-RapidAPI-Key": API_KEY,
	"X-RapidAPI-Host": "realty-mole-property-api.p.rapidapi.com"
}

response_RichmondH = requests.request("GET", url, headers=headers, params=querystring).json()

print(json.dumps(response_RichmondH, indent=4, sort_keys=True))
# Out:
# []

# %%
# API setup

url = "https://realty-mole-property-api.p.rapidapi.com/saleListings"

querystring = {"zipCode":"23232","limit":"500"}

headers = {
	"X-RapidAPI-Key": API_KEY,
	"X-RapidAPI-Host": "realty-mole-property-api.p.rapidapi.com"
}

response_RichmondI = requests.request("GET", url, headers=headers, params=querystring).json()

print(json.dumps(response_RichmondI, indent=4, sort_keys=True))
# Out:
# []

# %%
# API setup

url = "https://realty-mole-property-api.p.rapidapi.com/saleListings"

querystring = {"zipCode":"23241","limit":"500"}

headers = {
	"X-RapidAPI-Key": API_KEY,
	"X-RapidAPI-Host": "realty-mole-property-api.p.rapidapi.com"
}

response_RichmondJ = requests.request("GET", url, headers=headers, params=querystring).json()

print(json.dumps(response_RichmondJ, indent=4, sort_keys=True))
# Out:
# []

# %%
# API setup

url = "https://realty-mole-property-api.p.rapidapi.com/saleListings"

querystring = {"zipCode":"23249","limit":"500"}

headers = {
	"X-RapidAPI-Key": API_KEY,
	"X-RapidAPI-Host": "realty-mole-property-api.p.rapidapi.com"
}

response_RichmondK = requests.request("GET", url, headers=headers, params=querystring).json()

print(json.dumps(response_RichmondK, indent=4, sort_keys=True))
# Out:
# []

# %%
# API setup

url = "https://realty-mole-property-api.p.rapidapi.com/saleListings"

querystring = {"zipCode":"23261","limit":"500"}

headers = {
	"X-RapidAPI-Key": API_KEY,
	"X-RapidAPI-Host": "realty-mole-property-api.p.rapidapi.com"
}

response_RichmondL = requests.request("GET", url, headers=headers, params=querystring).json()

print(json.dumps(response_RichmondL, indent=4, sort_keys=True))
# Out:
# []

# %%
# API setup

url = "https://realty-mole-property-api.p.rapidapi.com/saleListings"

querystring = {"zipCode":"23260","limit":"500"}

headers = {
	"X-RapidAPI-Key": API_KEY,
	"X-RapidAPI-Host": "realty-mole-property-api.p.rapidapi.com"
}

response_RichmondM = requests.request("GET", url, headers=headers, params=querystring).json()

print(json.dumps(response_RichmondM, indent=4, sort_keys=True))
# Out:
# [
#     {
#         "addressLine1": "3807 Duckling Walk",
#         "bathrooms": 4.5,
#         "bedrooms": 5,
#         "city": "Richmond",
#         "county": "Henrico County",
#         "createdDate": "2021-02-11T11:38:36.555Z",
#         "daysOnMarket": 544,
#         "formattedAddress": "3807 Duckling Walk, Richmond, VA 23260",
#         "id": "3807-Duckling-Walk,-Richmond,-VA-23260",
#         "lastSeen": "2021-03-14T13:48:46.864Z",
#         "latitude": 37.646029,
#         "listedDate": "2021-02-11T11:38:36.555Z",
#         "longitude": -77.602298,
#         "price": 550000,
#         "propertyType": "Condo",
#         "removedDate": "2022-08-08T16:52:50.653Z",
#         "squareFootage": 2952,
#         "state": "VA",
#         "status": "Inactive",
#         "zipCode": "23260"
#     }
# ]

# %%
# API setup

url = "https://realty-mole-property-api.p.rapidapi.com/saleListings"

querystring = {"zipCode":"23269","limit":"500"}

headers = {
	"X-RapidAPI-Key": API_KEY,
	"X-RapidAPI-Host": "realty-mole-property-api.p.rapidapi.com"
}

response_RichmondN = requests.request("GET", url, headers=headers, params=querystring).json()

print(json.dumps(response_RichmondN, indent=4, sort_keys=True))
# Out:
# []

# %%
# API setup

url = "https://realty-mole-property-api.p.rapidapi.com/saleListings"

querystring = {"zipCode":"23274","limit":"500"}

headers = {
	"X-RapidAPI-Key": API_KEY,
	"X-RapidAPI-Host": "realty-mole-property-api.p.rapidapi.com"
}

response_RichmondO = requests.request("GET", url, headers=headers, params=querystring).json()

print(json.dumps(response_RichmondO, indent=4, sort_keys=True))
# Out:
# []

# %%
# API setup

url = "https://realty-mole-property-api.p.rapidapi.com/saleListings"

querystring = {"zipCode":"23278","limit":"500"}

headers = {
	"X-RapidAPI-Key": API_KEY,
	"X-RapidAPI-Host": "realty-mole-property-api.p.rapidapi.com"
}

response_RichmondP = requests.request("GET", url, headers=headers, params=querystring).json()

print(json.dumps(response_RichmondP, indent=4, sort_keys=True))
# Out:
# []

# %%
# API setup

url = "https://realty-mole-property-api.p.rapidapi.com/saleListings"

querystring = {"zipCode":"23285","limit":"500"}

headers = {
	"X-RapidAPI-Key": API_KEY,
	"X-RapidAPI-Host": "realty-mole-property-api.p.rapidapi.com"
}

response_RichmondQ = requests.request("GET", url, headers=headers, params=querystring).json()

print(json.dumps(response_RichmondQ, indent=4, sort_keys=True))
# Out:
# []

# %%
# API setup

url = "https://realty-mole-property-api.p.rapidapi.com/saleListings"

querystring = {"zipCode":"23286","limit":"500"}

headers = {
	"X-RapidAPI-Key": API_KEY,
	"X-RapidAPI-Host": "realty-mole-property-api.p.rapidapi.com"
}

response_RichmondR = requests.request("GET", url, headers=headers, params=querystring).json()

print(json.dumps(response_RichmondR, indent=4, sort_keys=True))
# Out:
# []

# %%
# API setup

url = "https://realty-mole-property-api.p.rapidapi.com/saleListings"

querystring = {"zipCode":"23290","limit":"500"}

headers = {
	"X-RapidAPI-Key": API_KEY,
	"X-RapidAPI-Host": "realty-mole-property-api.p.rapidapi.com"
}

response_RichmondS = requests.request("GET", url, headers=headers, params=querystring).json()

print(json.dumps(response_RichmondS, indent=4, sort_keys=True))
# Out:
# []

# %%
# API setup

url = "https://realty-mole-property-api.p.rapidapi.com/saleListings"

querystring = {"zipCode":"23289","limit":"500"}

headers = {
	"X-RapidAPI-Key": API_KEY,
	"X-RapidAPI-Host": "realty-mole-property-api.p.rapidapi.com"
}

response_RichmondT = requests.request("GET", url, headers=headers, params=querystring).json()

print(json.dumps(response_RichmondT, indent=4, sort_keys=True))
# Out:
# []

# %%
# API setup

url = "https://realty-mole-property-api.p.rapidapi.com/saleListings"

querystring = {"zipCode":"23292","limit":"500"}

headers = {
	"X-RapidAPI-Key": API_KEY,
	"X-RapidAPI-Host": "realty-mole-property-api.p.rapidapi.com"
}

response_RichmondU = requests.request("GET", url, headers=headers, params=querystring).json()

print(json.dumps(response_RichmondU, indent=4, sort_keys=True))
# Out:
# []

# %%
# API setup

url = "https://realty-mole-property-api.p.rapidapi.com/saleListings"

querystring = {"zipCode":"23291","limit":"500"}

headers = {
	"X-RapidAPI-Key": API_KEY,
	"X-RapidAPI-Host": "realty-mole-property-api.p.rapidapi.com"
}

response_RichmondV = requests.request("GET", url, headers=headers, params=querystring).json()

print(json.dumps(response_RichmondV, indent=4, sort_keys=True))
# Out:
# []

# %%
# API setup

url = "https://realty-mole-property-api.p.rapidapi.com/saleListings"

querystring = {"zipCode":"23293","limit":"500"}

headers = {
	"X-RapidAPI-Key": API_KEY,
	"X-RapidAPI-Host": "realty-mole-property-api.p.rapidapi.com"
}

response_RichmondW = requests.request("GET", url, headers=headers, params=querystring).json()

print(json.dumps(response_RichmondW, indent=4, sort_keys=True))
# Out:
# []

# %%
df = pd.DataFrame(response_RichmondA)
print(df)
# Out:
#      bedrooms   price               county   propertyType  \
# 0         0.0   90000  Chesterfield County           Land
# 1         NaN  129000             Richmond           Land
# 2         3.0  280000             Richmond  Single Family
# 3         NaN   49999             Richmond           Land
# 4         3.0  169900             Richmond  Single Family
# ..        ...     ...                  ...            ...
# 387       3.0  175000  Chesterfield County          Condo
# 388       3.0  239950  Chesterfield County  Single Family
# 389       3.0  164950  Chesterfield County          Condo
# 390       2.0  145000  Chesterfield County          Condo
# 391       3.0  195000  Chesterfield County  Single Family
#
#                addressLine1      city state zipCode  \
# 0     2527 Goodes Bridge Rd  Richmond    VA   23224
# 1        2401 Clearfield St  Richmond    VA   23224
# 2           4925 Warwick Rd  Richmond    VA   23224
# 3          5400 Hansdale Rd  Richmond    VA   23224
# ...

# %%
df.dtypes
# Out:
# bedrooms            float64
# price                 int64
# county               object
# propertyType         object
# addressLine1         object
# city                 object
# state                object
# zipCode              object
# formattedAddress     object
# lastSeen             object
# listedDate           object
# status               object
# removedDate          object
# daysOnMarket          int64
# createdDate          object
# lotSize             float64
# id                   object
# latitude            float64
# longitude           float64
# bathrooms           float64
# squareFootage       float64
# yearBuilt           float64
# addressLine2         object
# dtype: object

# %%
dfA = pd.DataFrame(response_RichmondA)
dfB = pd.DataFrame(response_RichmondB)
dfC = pd.DataFrame(response_RichmondC)
dfD = pd.DataFrame(response_RichmondD)
dfE = pd.DataFrame(response_RichmondE)
dfF = pd.DataFrame(response_RichmondF)
dfG = pd.DataFrame(response_RichmondG)
dfH = pd.DataFrame(response_RichmondH)
dfI = pd.DataFrame(response_RichmondI)
dfJ = pd.DataFrame(response_RichmondJ)
dfK = pd.DataFrame(response_RichmondK)
dfL = pd.DataFrame(response_RichmondL)
dfM = pd.DataFrame(response_RichmondM)
dfN = pd.DataFrame(response_RichmondN)
dfO = pd.DataFrame(response_RichmondO)
dfP = pd.DataFrame(response_RichmondP)
dfQ = pd.DataFrame(response_RichmondQ)
dfR = pd.DataFrame(response_RichmondR)
dfS = pd.DataFrame(response_RichmondS)
dfT = pd.DataFrame(response_RichmondT)
dfU = pd.DataFrame(response_RichmondU)
dfV = pd.DataFrame(response_RichmondV)
dfW = pd.DataFrame(response_RichmondW)

# %%
import os  
os.makedirs('CSV', exist_ok=True)  
dfA.to_csv('CSV/23224.csv')
dfB.to_csv('CSV/23220.csv')  
dfC.to_csv('CSV/23221.csv')  
dfD.to_csv('CSV/23219.csv')  
dfE.to_csv('CSV/23284.csv')  
dfF.to_csv('CSV/23298.csv')  
dfG.to_csv('CSV/23240.csv')  
dfH.to_csv('CSV/23218.csv')  
dfI.to_csv('CSV/23232.csv')  
dfJ.to_csv('CSV/23241.csv')  
dfK.to_csv('CSV/23249.csv')  
dfL.to_csv('CSV/23261.csv')  
dfM.to_csv('CSV/23260.csv')  
dfN.to_csv('CSV/23269.csv')  
dfO.to_csv('CSV/23274.csv')  
dfP.to_csv('CSV/23278.csv')  
dfQ.to_csv('CSV/23285.csv')  
dfR.to_csv('CSV/23286.csv') 
dfS.to_csv('CSV/23290.csv') 
dfT.to_csv('CSV/23289.csv') 
dfU.to_csv('CSV/23292.csv') 
dfV.to_csv('CSV/23291.csv') 
dfW.to_csv('CSV/23293.csv')
