# %% [markdown]
# #### Question: Optimal price to put in for bid on a house
#
# Greater Richmond Area Cities
# ML model to best predict bid price based on house characteristics
#
# Heatmap of selling prices based on selling price parsed by zip code
# Hover text with name, avg selling price, etc
#
# Parameter Limits: 1 bathroom, 1 bedroom, PropertyType = Single Family, Townhouse, Condo, *Duplex-Triplex*, Manufactured

# %%
# Import the dependencies.
import pandas as pd
import requests
import json

# %%
# API setup

import requests

url = "https://realty-mole-property-api.p.rapidapi.com/saleListings"

querystring = {"city":"Richmond","state":"VA","limit":"50"}

headers = {
	"X-RapidAPI-Key": "21b9141130msh5a54b26b49ce191p18d187jsn33ad80884206",
	"X-RapidAPI-Host": "realty-mole-property-api.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring).json()

print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# [
#     {
#         "addressLine1": "5508 Eanes Ln",
#         "bathrooms": 3,
#         "bedrooms": 0,
#         "city": "Richmond",
#         "county": "Henrico County",
#         "createdDate": "2021-08-08T07:22:35.837Z",
#         "daysOnMarket": 375,
#         "formattedAddress": "5508 Eanes Ln, Richmond, VA 23231",
#         "id": "5508-Eanes-Ln,-Richmond,-VA-23231",
#         "lastSeen": "2022-11-14T12:45:07.502Z",
#         "latitude": 37.51279,
#         "listedDate": "2021-11-04T16:18:52.000Z",
#         "longitude": -77.382872,
#         "lotSize": 20517,
#         "price": 25000,
#         "propertyType": "Land",
#         "removedDate": null,
#         "squareFootage": 1919,
#         "state": "VA",
#         "status": "Active",
#         "zipCode": "23231"
#     },
#     {
#         "addressLine1": "1384 Harmony Ave",
#         "bedrooms": 0,
#         "city": "Richmond",
#         "county": "Henrico County",
#         "createdDate": "2021-02-13T06:25:24.176Z",
# ...
