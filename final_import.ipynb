# %%
import pandas as pd
import os 
from sqlalchemy import create_engine
from config import db_password
from sqlalchemy.ext.declarative import declarative_base

# %%
import glob

# %%
file_path = "Resources/"

# %%
db_string = f"postgresql://postgres:{db_password}@127.0.0.1:5432/rva_real_estate"
engine = create_engine(db_string)

# %%
file_list = os.listdir(file_path)
file_list
# Out:
# ['23284.csv',
#  '23290.csv',
#  '23291.csv',
#  '23285.csv',
#  '23250.csv',
#  '23278.csv',
#  '23293.csv',
#  '23286.csv',
#  '23292.csv',
#  '23279.csv',
#  '23047.csv',
#  '23269.csv',
#  '.DS_Store',
#  '23255.csv',
#  '23241.csv',
#  '23282.csv',
#  '23297.csv',
#  '23240.csv',
#  '23120.csv',
#  '23242.csv',
#  '23294.csv',
#  '23280.csv',
#  '23069.csv',
#  '23146.csv',
#  '23224.csv',
#  '23230.csv',
#  '23218.csv',
#  '23219.csv',
#  '23231.csv',
#  '23225.csv',
#  '23806.csv',
#  '23838.csv',
#  '23192.csv',
#  '23233.csv',
#  '23227.csv',
#  '23226.csv',
#  '23232.csv',
#  '23150.csv',
#  '23236.csv',
#  '23222.csv',
#  '23223.csv',
#  '23237.csv',
#  '23221.csv',
#  '23235.csv',
#  '23234.csv',
#  '23220.csv',
#  '23803.csv',
#  '23173.csv',
#  '23832.csv',
#  '23238.csv',
#  '23831.csv',
#  '23005.csv',
#  '23834.csv',
#  '23015.csv',
#  '23162.csv',
#  '23228.csv',
#  '23229.csv',
#  '23836.csv',
#  '23058.csv',
#  '23298.csv',
#  '23273.csv',
#  '23059.csv',
# ...

# %%
#list all csv files only
csv_files = glob.glob('Resources/*.{}'.format('csv'))
csv_files
# Out:
# ['Resources/23284.csv',
#  'Resources/23290.csv',
#  'Resources/23291.csv',
#  'Resources/23285.csv',
#  'Resources/23250.csv',
#  'Resources/23278.csv',
#  'Resources/23293.csv',
#  'Resources/23286.csv',
#  'Resources/23292.csv',
#  'Resources/23279.csv',
#  'Resources/23047.csv',
#  'Resources/23269.csv',
#  'Resources/23255.csv',
#  'Resources/23241.csv',
#  'Resources/23282.csv',
#  'Resources/23297.csv',
#  'Resources/23240.csv',
#  'Resources/23120.csv',
#  'Resources/23242.csv',
#  'Resources/23294.csv',
#  'Resources/23280.csv',
#  'Resources/23069.csv',
#  'Resources/23146.csv',
#  'Resources/23224.csv',
#  'Resources/23230.csv',
#  'Resources/23218.csv',
#  'Resources/23219.csv',
#  'Resources/23231.csv',
#  'Resources/23225.csv',
#  'Resources/23806.csv',
#  'Resources/23838.csv',
#  'Resources/23192.csv',
#  'Resources/23233.csv',
#  'Resources/23227.csv',
#  'Resources/23226.csv',
#  'Resources/23232.csv',
#  'Resources/23150.csv',
#  'Resources/23236.csv',
# ...

# %%
# Combine all CSVs in dataframe
df_all_data = pd.concat([pd.read_csv(f) for f in csv_files ], ignore_index=True)
df_all_data
# Out:
#       Unnamed: 0  bedrooms      price               county   propertyType  \
# 0              0       0.0   153700.0       Hanover County           Land
# 1              1       0.0   400000.0       Hanover County           Land
# 2              2       5.0  2200000.0       Hanover County  Single Family
# 3              3       4.0   628900.0       Hanover County  Single Family
# 4              4       3.0   309900.0       Hanover County  Single Family
# ...          ...       ...        ...                  ...            ...
# 17487        495       4.0   325000.0  Chesterfield County  Single Family
# 17488        496       3.0   307000.0  Chesterfield County  Single Family
# 17489        497       4.0   309000.0  Chesterfield County  Single Family
# 17490        498       4.0   299950.0  Chesterfield County  Single Family
# 17491        499       3.0   259900.0  Chesterfield County  Single Family
#
#                 addressLine1        city state  zipCode  \
# ...

# %%
# Export dataframe to csv
df_all_data.to_csv('all_data.csv')

# %%
# Export CSV to postgreSQL database
data = pd.read_csv('Resources/all_data.csv')

# %%
# Export CSV to postgreSQL database
data.to_sql('all_data', db_string)
# Out:
# 492
